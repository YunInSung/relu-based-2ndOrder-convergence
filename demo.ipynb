# %% [markdown]
# <a href="https://colab.research.google.com/github/YunInSung/relu-based-2ndOrder-convergence/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1️⃣ 셀 1: 환경 설정 & 라이브러리 설치

# %%
## (필요하다면) Colab 런타임 유형 👉 GPU 선택
# !git clone https://github.com/YunInSung/relu-based-2ndOrder-convergence.git
# %cd relu-based-2ndOrder-convergence

## requirements.txt에 적어둔 패키지를 강제 재설치
# !pip install -q --force-reinstall -r requirements.txt

# %%
#2️⃣셀 2: 간단 실행 데모

# %%
# !python experiment_runner.py \
    --epochs 5 \
    --datasets Gauss_sep0.5_clust1 \
    --num_repeats 2 \
    --hidden_layer_size 5 \
    --batch_size 64

# %%
#3️⃣셀 3: 결과 확인

# %%
## 로그 폴더에 생성된 CSV 불러와서 확인
import pandas as pd

df = pd.read_csv('logs/experiment_results.csv')
df.head()
# !python plot_from_csv.py
# !python plot_results.py

# %%
# 4️⃣ 셀 4: figure 디렉토리 확인 및 이미지 표시

# %%
import os
from IPython.display import display, Image, Markdown

fig_dir = "figures"
## png/jpg/jpeg/gif 확장자만 골라서, 실제 파일인지 확인
image_files = sorted(
    f for f in os.listdir(fig_dir)
    if os.path.isfile(os.path.join(fig_dir, f))
    and f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))
)

display(Markdown("## All Saved Figures"))
for fname in image_files:
    path = os.path.join(fig_dir, fname)
    display(Markdown(f"### {fname}"))
    display(Image(filename=path))
